# %% [markdown]
# # Python para Análise de Dados

# %%
import pandas as pd

# %% [markdown]
# * Lendo uma base de dados no formtao .csv
# * O parâmetro sep é usado para definir qual o separador entre os dados
# * O parâmetro header informa em qual linha está minhas colunas ou se elas não existem
# * Se não existe colunas (Header = nome) o pandas dará um nome para cada atributo da base

# %%
arquivo = 'kc_house_data.csv'

# %%
dataset = pd.read_csv(arquivo, sep=',', header=0)

# %% [markdown]
# * Imprimindo o tipo da variável dataset
# * Dataframe é uma estrutura de dados onde linhas podem ter colunas de diferentes tipos

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# * Método head() imprime as 5 linhas iniciais do dataframe

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# * O parâmetro index_col informa  coluna na qual o dataframe será indexado

# %%
dataset = pd.read_csv(arquivo, sep=',', index_col= 'date')

# %%
dataset.head()
# Out:
#                          id     price  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7129300520  221900.0       3.0       1.00         1180
# 20141209T000000  6414100192  538000.0       3.0       2.25         2570
# 20150225T000000  5631500400  180000.0       2.0       1.00          770
# 20141209T000000  2487200875  604000.0       4.0       3.00         1960
# 20150218T000000  1954400510  510000.0       3.0       2.00         1680
#
#                  sqft_lot  floors  waterfront  view  condition  grade  \
# date
# 20141013T000000      5650     1.0           0     0          3      7
# 20141209T000000      7242     2.0           0     0          3      7
# 20150225T000000     10000     1.0           0     0          3      6
# 20141209T000000      5000     1.0           0     0          5      7
# 20150218T000000      8080     1.0           0     0          3      8
#
#                  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# date
# ...

# %%
dataset = pd.read_csv(arquivo, sep=',', usecols=['id', 'date', 'price', 'bedrooms'])

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms
# 0  7129300520  20141013T000000  221900.0       3.0
# 1  6414100192  20141209T000000  538000.0       3.0
# 2  5631500400  20150225T000000  180000.0       2.0
# 3  2487200875  20141209T000000  604000.0       4.0
# 4  1954400510  20150218T000000  510000.0       3.0

# %% [markdown]
# * Imprimindo as 100 primeiras linhas do dataframe

# %%
dataset.head(100)
# Out:
#             id             date      price  bedrooms
# 0   7129300520  20141013T000000   221900.0       3.0
# 1   6414100192  20141209T000000   538000.0       3.0
# 2   5631500400  20150225T000000   180000.0       2.0
# 3   2487200875  20141209T000000   604000.0       4.0
# 4   1954400510  20150218T000000   510000.0       3.0
# 5   7237550310  20140512T000000  1225000.0       4.0
# 6   1321400060  20140627T000000   257500.0       3.0
# 7   2008000270  20150115T000000   291850.0       3.0
# 8   2414600126  20150415T000000   229500.0       3.0
# 9   3793500160  20150312T000000   323000.0       3.0
# 10  1736800520  20150403T000000   662500.0       3.0
# 11  9212900260  20140527T000000   468000.0       2.0
# 12   114101516  20140528T000000   310000.0       3.0
# 13  6054650070  20141007T000000   400000.0       3.0
# 14  1175000570  20150312T000000   530000.0       5.0
# 15  9297300055  20150124T000000   650000.0       4.0
# 16  1875500060  20140731T000000   395000.0       3.0
# ...

# %% [markdown]
# * Atributo columns retorna o nome das colunas do dataframe

# %%
dataset.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms'], dtype='object')

# %% [markdown]
# * método count() retorna a quantidade de linhas de todas as colunas

# %%
dataset.count()
# Out:
# id          21613
# date        21613
# price       21613
# bedrooms    21609
# dtype: int64

# %% [markdown]
# * Método describe() exibe informações estatísticas da base de dados
# * Várias informações como desvio padrão, média, valor mínimo e valor máximo de colunas

# %%
dataset.describe()
# Out:
#                  id         price      bedrooms
# count  2.161300e+04  2.161300e+04  21609.000000
# mean   4.580302e+09  5.400881e+05      3.370910
# std    2.876566e+09  3.671272e+05      0.930084
# min    1.000102e+06  7.500000e+04      0.000000
# 25%    2.123049e+09  3.219500e+05      3.000000
# 50%    3.904930e+09  4.500000e+05      3.000000
# 75%    7.308900e+09  6.450000e+05      4.000000
# max    9.900000e+09  7.700000e+06     33.000000

# %% [markdown]
# * Imprime as 5 últimas linhas

# %%
dataset.tail()
# Out:
#                id             date     price  bedrooms
# 21608   263000018  20140521T000000  360000.0       3.0
# 21609  6600060120  20150223T000000  400000.0       4.0
# 21610  1523300141  20140623T000000  402101.0       2.0
# 21611   291310100  20150116T000000  400000.0       3.0
# 21612  1523300157  20141015T000000  325000.0       2.0

# %% [markdown]
# * Imprime uma amostra aleatória do dataset

# %%
dataset.sample(5)
# Out:
#                id             date      price  bedrooms
# 9294   1257201095  20150323T000000   826000.0       2.0
# 20326  1725059127  20150225T000000  2350000.0       6.0
# 20189   745500010  20141208T000000   730000.0       4.0
# 9914   6137500310  20150213T000000  1315000.0       5.0
# 17387  6413600290  20140509T000000   252500.0       3.0

# %% [markdown]
# * Retorna um formato de tupla - quantidade de linhas e colunas do dataset

# %%
dataset.shape
# Out:
# (21613, 4)

# %% [markdown]
# * Imprime informações sobre cplunas e usa de memória

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
# id          21613 non-null int64
# date        21613 non-null object
# price       21613 non-null float64
# bedrooms    21609 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 675.5+ KB
